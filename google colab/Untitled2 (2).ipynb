# %%
import pandas as pd

# %%
df = pd.read_csv('/content/dados.csv')

# %% [markdown]
# #tabela de dados

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # valor maximo,minimo e media da materia math score

# %%
df ['math score'].max()
# Out:
# 100

# %%
df [ 'math score'].min()
# Out:
# 0

# %%
df [ 'math score'].mean()
# Out:
# 66.089

# %%
valor maior da materia matematica foi:100; a menor foi: 0 e media foi:66.089

# %% [markdown]
# # valor maximo,minimo e media da materia reading score

# %%
df ['reading score'].max()
# Out:
# 100

# %%
df [ 'reading score'].min()
# Out:
# 17

# %%
df['reading score'].mean()
# Out:
# 69.169

# %% [markdown]
# # valor maximo,minimo e media da materia writing score

# %%
df['writing score'].max()
# Out:
# 100

# %%
df['writing score'].min()
# Out:
# 10

# %%
df['writing score'].mean()
# Out:
# 68.054

# %% [markdown]
# # agrupamendo do banco de dados e a media

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.groupby('race/ethnicity').mean()
# Out:
# <ipython-input-41-196c2a90d9af>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('race/ethnicity').mean()
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143

# %% [markdown]
# # Agrupar o banco de dados a partir da coluna referente à participação
# #em um curso preparatório para os testes e plotar

# %%
import matplotlib.pyplot as plt

# %%
df.groupby('parental level of education').sum()
# Out:
# <ipython-input-59-07422998e165>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('parental level of education').sum()
#                              math score  reading score  writing score
# parental level of education
# associate's degree                15070          15746          15517
# bachelor's degree                  8188           8614           8659
# high school                       12179          12682          12240
# master's degree                    4115           4447           4465
# some college                      15171          15698          15558
# some high school                  11366          11982          11615

# %%
df = pd.read_csv('/content/dados.csv')

# %%
df2 = df.groupby('test preparation course')[['writing score']].mean()

# %%
df2
# Out:
#                          writing score
# test preparation course
# completed                    74.418994
# none                         64.504673

# %%
df2.plot(kind= 'barh')
# Out:
# <Axes: ylabel='test preparation course'>
